# %%
#import requests
#from bs4 import BeautifulSoup

import pandas as pd
import numpy as np
import time

import seaborn
from matplotlib import pyplot

from sklearn.linear_model import LogisticRegression

# %load_ext sql

# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %sql duckdb:///:memory:

# %%
chess_games_cleaned = pd.read_csv("chess_games_cleaned.csv")

chess_games_cleaned = chess_games_cleaned.drop("Unnamed: 0", axis = 1)

chess_games_cleaned
# Out:
#        Result  WhiteElo  BlackElo  WhiteRatingDiff  ECO  \
# 0         1-0      1901      1896                5  D10
# 1         0-1      1641      1627               14  C20
# 2         1-0      1647      1688              -41  B01
# 3         0-1      1945      1900               45  B90
# 4         0-1      1773      1809              -36  C27
# ...       ...       ...       ...              ...  ...
# 621597    0-1      1798      1753               45  B06
# 621598    0-1      1711      1578              133  B08
# 621599    1-0      1762      1683               79  C00
# 621600    1-0      2023      1742              281  A45
# 621601    0-1      2094      1931              163  A40
#
#                                               Opening TimeControl  \
# 0                                        Slav Defense       300+5
# 1                           King's Pawn Opening: 2.b3       300+0
# 2       Scandinavian Defense: Mieses-Kotroc Variation       180+0
# 3         Sicilian Defense: Najdorf, Lipnitsky Attack       180+0
# 4                                         Vienna Game       180+0
# ...                                               ...         ...
# 621597                                 Modern Defense        60+0
# 621598              Pirc Defense: Classical Variation       300+0
# 621599                             St. George Defense       300+4
# 621600                                    Indian Game       180+0
# 621601                                 Modern Defense       600+0
#
#          Termination  Base (min)  Increment (sec)
# 0       Time forfeit         5.0                5
# 1             Normal         5.0                0
# 2       Time forfeit         3.0                0
# 3       Time forfeit         3.0                0
# 4             Normal         3.0                0
# ...              ...         ...              ...
# 621597  Time forfeit         1.0                0
# 621598        Normal         5.0                0
# 621599        Normal         5.0                4
# 621600        Normal         3.0                0
# 621601        Normal        10.0                0
#
# [621602 rows x 10 columns]

# %%
# %sql SELECT * FROM chess_games_cleaned WHERE Opening = "Slav Defense"
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/opt/anaconda3/envs/info2950/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1900, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1899     if not evt_handled:
# -> 1900         self.dialect.do_execute(
#    1901             cursor, statement, parameters, context
#    1902         )
#    1904 if self._has_events or self.engine._has_events:
#
# File ~/opt/anaconda3/envs/info2950/lib/python3.8/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~/opt/anaconda3/envs/info2950/lib/python3.8/site-packages/duckdb_engine/__init__.py:123, in ConnectionWrapper.execute(self, statement, parameters, context)
#     122 else:
# --> 123     raise e
#
# File ~/opt/anaconda3/envs/info2950/lib/python3.8/site-packages/duckdb_engine/__init__.py:113, in ConnectionWrapper.execute(self, statement, parameters, context)
#     112     else:
# --> 113         self.c.execute(statement, parameters)
#     114 except RuntimeError as e:
#
# RuntimeError: Binder Error: Referenced column "Slav Defense" not found in FROM clause!
# Candidate bindings: "chess_games_cleaned.BlackElo"
# LINE 1: ...OM chess_games_cleaned WHERE Opening = "Slav Defense"
#                                                   ^
#
# The above exception was the direct cause of the following exception:
#
# DBAPIError                                Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 get_ipython().run_line_magic('sql', 'SELECT * FROM chess_games_cleaned WHERE Opening = "Slav Defense"')
#
# File ~/opt/anaconda3/envs/info2950/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2305, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2303     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2304 with self.builtin_trap:
# -> 2305     result = fn(*args, **kwargs)
#    2306 return result
#
# File ~/opt/anaconda3/envs/info2950/lib/python3.8/site-packages/sql/magic.py:215, in SqlMagic.execute(self, line, cell, local_ns)
#     212     return
#     214 try:
# --> 215     result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     217     if (
#     218         result is not None
#     219         and not isinstance(result, str)
#    (...)
#     222         # Instead of returning values, set variables directly in the
#     223         # users namespace. Variable names given by column names
#     225         if self.autopandas:
#
# File ~/opt/anaconda3/envs/info2950/lib/python3.8/site-packages/sql/run.py:370, in run(conn, sql, config, user_namespace)
#     368 else:
#     369     txt = sqlalchemy.sql.text(statement)
# --> 370     result = conn.session.execute(txt, user_namespace)
#     371 _commit(conn=conn, config=config)
#     372 if result and config.feedback:
#
# File ~/opt/anaconda3/envs/info2950/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1380, in Connection.execute(self, statement, *multiparams, **params)
#    1376     util.raise_(
#    1377         exc.ObjectNotExecutableError(statement), replace_context=err
#    1378     )
#    1379 else:
# -> 1380     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File ~/opt/anaconda3/envs/info2950/lib/python3.8/site-packages/sqlalchemy/sql/elements.py:333, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     329 def _execute_on_connection(
#     330     self, connection, multiparams, params, execution_options, _force=False
#     331 ):
#     332     if _force or self.supports_execution:
# --> 333         return connection._execute_clauseelement(
#     334             self, multiparams, params, execution_options
#     335         )
#     336     else:
#     337         raise exc.ObjectNotExecutableError(self)
#
# File ~/opt/anaconda3/envs/info2950/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1572, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1560 compiled_cache = execution_options.get(
#    1561     "compiled_cache", self.engine._compiled_cache
#    1562 )
#    1564 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1565     dialect=dialect,
#    1566     compiled_cache=compiled_cache,
#    (...)
#    1570     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1571 )
# -> 1572 ret = self._execute_context(
#    1573     dialect,
#    1574     dialect.execution_ctx_cls._init_compiled,
#    1575     compiled_sql,
#    1576     distilled_params,
#    1577     execution_options,
#    1578     compiled_sql,
#    1579     distilled_params,
#    1580     elem,
#    1581     extracted_params,
#    1582     cache_hit=cache_hit,
#    1583 )
#    1584 if has_events:
#    1585     self.dispatch.after_execute(
#    1586         self,
#    1587         elem,
#    (...)
#    1591         ret,
#    1592     )
#
# File ~/opt/anaconda3/envs/info2950/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1943, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1940             branched.close()
#    1942 except BaseException as e:
# -> 1943     self._handle_dbapi_exception(
#    1944         e, statement, parameters, cursor, context
#    1945     )
#    1947 return result
#
# File ~/opt/anaconda3/envs/info2950/lib/python3.8/site-packages/sqlalchemy/engine/base.py:2124, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2122     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2123 elif should_wrap:
# -> 2124     util.raise_(
#    2125         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2126     )
#    2127 else:
#    2128     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~/opt/anaconda3/envs/info2950/lib/python3.8/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File ~/opt/anaconda3/envs/info2950/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1900, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1898                 break
#    1899     if not evt_handled:
# -> 1900         self.dialect.do_execute(
#    1901             cursor, statement, parameters, context
#    1902         )
#    1904 if self._has_events or self.engine._has_events:
#    1905     self.dispatch.after_cursor_execute(
#    1906         self,
#    1907         cursor,
#    (...)
#    1911         context.executemany,
#    1912     )
#
# File ~/opt/anaconda3/envs/info2950/lib/python3.8/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~/opt/anaconda3/envs/info2950/lib/python3.8/site-packages/duckdb_engine/__init__.py:123, in ConnectionWrapper.execute(self, statement, parameters, context)
#     121     return
#     122 else:
# --> 123     raise e
#
# File ~/opt/anaconda3/envs/info2950/lib/python3.8/site-packages/duckdb_engine/__init__.py:113, in ConnectionWrapper.execute(self, statement, parameters, context)
#     111         self.c.execute(statement)
#     112     else:
# --> 113         self.c.execute(statement, parameters)
#     114 except RuntimeError as e:
#     115     if e.args[0].startswith("Not implemented Error"):
#
# DBAPIError: (builtins.RuntimeError) Binder Error: Referenced column "Slav Defense" not found in FROM clause!
# Candidate bindings: "chess_games_cleaned.BlackElo"
# LINE 1: ...OM chess_games_cleaned WHERE Opening = "Slav Defense"
#                                                   ^
# [SQL: SELECT * FROM chess_games_cleaned WHERE Opening = "Slav Defense"]
# (Background on this error at: https://sqlalche.me/e/14/dbapi)
